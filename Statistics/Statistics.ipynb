# %%
import pandas as pd

df = pd.DataFrame({'Name': ['Jane', 'Michael', 'Willian', 'Rosy', 'Hana', 'Ferdie', 'Graeme'], 'Salary': [50000,54000,50000,189000,55000,40000,59000]})
print(df.head())
# Out:
#       Name  Salary
# 0     Jane   50000
# 1  Michael   54000
# 2  Willian   50000
# 3     Rosy  189000
# 4     Hana   55000

# %%
#Calculate the mean, median

print('Min: ' + str(df['Salary'].min()))
print('Max: ' + str(df['Salary'].max()))
print('mean', df['Salary'].mean())
print('median',df['Salary'].median())
print('mode',df['Salary'].mode())
print('range',df['Salary'].max() - df['Salary'].min())
# Out:
# Min: 40000
# Max: 189000
# mean 71000.0
# median 54000.0
# mode 0    50000
# dtype: int64
# range 149000

# %%
df['Salary'].describe()
df['Salary'].describe()['mean']
# Out:
# 71000.0

# %%
#histogram of salaries

# %matplotlib inline
import matplotlib.pyplot as plt

print(df)

df = pd.DataFrame({'Name': ['Jane', 'Michael', 'Willian', 'Rosy', 'Hana', 'Ferdie', 'Graeme'], 'Salary': [50000,54000,50000,189000,55000,40000,59000]})
salary = df['Salary']
salary.plot.hist(title= 'Salary Distribution', color='grey', bins=25)
plt.axvline(salary.mean(), color='violet', linestyle='dashed', linewidth=2)
plt.axvline(salary.median(), color='red', linestyle='dashed', linewidth=2)
plt.show()
# Out:
#       Name  Salary
# 0     Jane   50000
# 1  Michael   54000
# 2  Willian   50000
# 3     Rosy  189000
# 4     Hana   55000
# 5   Ferdie   40000
# 6   Graeme   59000
